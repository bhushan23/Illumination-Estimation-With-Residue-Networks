# %%
from utils import *
from data_loading import *
from models import *

# %%
path = '/home/bhushan/work/thesis/sfsnet/SC-Net/data/celeba_20k/'
syn_train_csv = None
celeba_train_csv = path + 'train.csv'
read_first = 1000
batch_size = 16
train_dataset, _ = get_sfsnet_dataset(syn_dir=None, read_from_csv=None, read_celeba_csv=celeba_train_csv, read_first=read_first, validation_split=1)
syn_train_dl  = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
d_iter = iter(syn_train_dl)

# %%
albedo, normal, mask, sh, face = next(d_iter)

# %%
path = '/home/bhushan/work/thesis/sfsnet/report/images/out/dataset/'
normal = get_normal_in_range(normal)
save_image(albedo, path = path+'albedo.png')
save_image(normal, path = path+'normal.png')
save_image(face, path = path+'face.png')

# %%
model = SfsNetPipeline()

# %%
print(model)
# Out:
# SfsNetPipeline(
#   (conv_model): baseFeaturesExtractions(
#     (conv1): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#       (3): Dropout(p=0)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#       (3): Dropout(p=0)
#     )
#     (conv3): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   )
#   (normal_residual_model): NormalResidualBlock(
#     (block1): ResNetBlock(
#       (res): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace)
#         (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...
